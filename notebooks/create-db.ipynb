# %%
from neomodel import config, db, StructuredNode, StringProperty, IntegerProperty, UniqueIdProperty, RelationshipTo

user = 'neo4j'
password = 'test'
config.DATABASE_URL = f'bolt://{user}:{password}@localhost:7687'
db.set_connection(f'bolt://{user}:{password}@localhost:7687')

# %%
class Author(StructuredNode):
    name = StringProperty(unique_index=True, required=True)
    
class Publisher(StructuredNode):
    name = StringProperty(unique_index=True, required=True)
    
class Year(StructuredNode):
    year = IntegerProperty(unique_index=True, required=True)

class Location(StructuredNode):
    name = StringProperty(unique_index=True, required=True)
    
class Fragment(StructuredNode):
    cluster_id = StringProperty(unique_index=True, required=True)

class Text(StructuredNode):
    text_id = StringProperty(unique_index=True, required=True)
    title = StringProperty()
    year = RelationshipTo(Year, 'PUBLICATION_YEAR')
    author = RelationshipTo(Author, 'HAS_AUTHOR')
    publisher = RelationshipTo(Publisher, 'HAS_PUBLISHER')
    location = RelationshipTo(Location, 'PUBLISHED_IN')
    fragment = RelationshipTo(Fragment, 'USES_FRAGMENT')

# %%
import json
texts = []

with open('../data/test_parse.json') as f:    
    texts = json.load(f)

# %%
import sys
import time

start = time.time()

for i, text in enumerate(texts):
    db_text = Text(text_id=text['id'], title=text['title']).save()
    for loc in text['pubplace']:
        loc_node = ''
        
        try:
            loc_node = Location.nodes.get(name=loc)
        except:
            loc_node = Location(name=loc).save()
        finally:
            db_text.location.connect(loc_node)
            
    for author in text.get('author', []):
        author_node = ''
        try:
            author_node = Author.nodes.get(name=author)
        except:
            author_node = Author(name=author).save()
        finally:
            db_text.author.connect(author_node)

    for publisher in text.get('publisher', []):
        pub_node = ''
        try:
            pub_node = Publisher.nodes.get(name=publisher)
        except:
            pub_node = Publisher(name=publisher).save()
        finally:
            db_text.publisher.connect(pub_node)

    try:
        if text.get('date', ''):
            year_node = ''
            year = int("".join(filter(lambda x: x.isnumeric(),  text['date'])))

            try:
                year_node = Year.nodes.get(year=year)
            except:
                year_node = Year(year=year).save()
            finally:
                db_text.year.connect(year_node)
    except:
        print('year failded', text)
            
    if i % 1000 == 999:
        print(f'Time since last checkpoint {time.time() - start} Progress at {i + 1} / {len(texts)}')
        start = time.time()
# Out:
# Time since last checkpoint 58.80594062805176 Progress at 1000 / 60327
# Time since last checkpoint 59.67611646652222 Progress at 2000 / 60327
# Time since last checkpoint 62.22266340255737 Progress at 3000 / 60327
# year failded {'id': 'A66970', 'title': "The Roman-church's devotions vindicated from Doctour Stillingfleet's mis-representation by O.N. a Catholick.", 'author': ['N. O.', 'R. H.', 'Cressy', 'Serenus'], 'pubplace': [], 'publisher': [], 'date': 'M.DC.LXXII.'}
# year failded {'id': 'A65465', 'title': "The pious communicant rightly prepar'd, or, A discourse concerning the Blessed Sacrament wherein the nature of it is described, our obligation to frequent communion enforced, and directions given for due preparation for it, behaviour at, and after it, and profiting by it : with prayers and hymns, suited to the several parts of that holy office : to which is added, a short discourse of baptism / by Samuel Wesley ...", 'author': ['Wesley, Samuel'], 'pubplace': ['London'], 'publisher': ['Charles Harper'], 'date': 'MDCC.'}
# Time since last checkpoint 61.68230366706848 Progress at 4000 / 60327
# year failded {'id': 'A21515', 'title': 'Instruccions geuen by the kynges maiestie, to his commissioners, appoynted for the execucion of certain statutes, made in the fourth yere of  the reigne of Kyng Henry the Seuenth and the vii and the xxvii yere of the reigne of Kyng Henry the Eight to be inquired of, iu [sic] the shires and places, in the commission hereunto annexed, expressed.', 'author': ['England', 'Wales', 'Edward VI', 'Edward VI', 'King of England'], 'pubplace': [], 'publisher': ['Richardi Graftoni'], 'date': 'Me[n]se Iulij, M.D.XLIX.'}
# year failded {'id': 'A23717', 'title': "Forty sermons whereof twenty one are now first publish'd, the greatest part preach'd before the King and on solemn occasions / by Richard Allestree ... ; to these is prefixt an account of the author's life.", 'author': ['Allestree', 'Richard', 'John'], 'pubplace': ['Theater', 'Oxford', 'London'], 'publisher': ['R. Scott', 'G. Wells', 'T. Sawbridge', 'R. Bentley'], 'date': 'MDCLXXXIV.'}
# Time since last checkpoint 63.08914756774902 Progress at 5000 / 60327
# Time since last checkpoint 64.76590609550476 Progress at 6000 / 60327
# Time since last checkpoint 66.92855072021484 Progress at 7000 / 60327
# Time since last checkpoint 63.622981548309326 Progress at 8000 / 60327
# year failded {'id': 'A96565', 'title': 'By the King, a proclamation for apprehending and securing the person of Robert Fielding', 'author': ['England', 'Wales', 'William III'], 'pubplace': ['London'], 'publisher': ['Charles Bill', 'Thomas Newcomb'], 'date': '169⁵/₆.'}
# Time since last checkpoint 53.5343177318573 Progress at 9000 / 60327
# Time since last checkpoint 62.528863191604614 Progress at 10000 / 60327
# Time since last checkpoint 64.87122631072998 Progress at 11000 / 60327
# Time since last checkpoint 63.58967971801758 Progress at 12000 / 60327
# Time since last checkpoint 62.51706647872925 Progress at 13000 / 60327
# Time since last checkpoint 60.55045032501221 Progress at 14000 / 60327
# year failded {'id': 'A51287', 'title': 'An appendix to the late antidote against idolatry Wherein the true and adequate notion or definition of idolatry is proposed. Most instances of idolatry in the Roman Church thereby examined. Sundry uses in the Church of England cleared. With some serious monitions touching spiritual idolatry thereunto annexed.', 'author': ['Henry'], 'pubplace': ['London'], 'publisher': ['I. R.', 'Walter Kettilby'], 'date': 'MDCLXXII,'}
# Time since last checkpoint 62.92399978637695 Progress at 15000 / 60327
# Time since last checkpoint 83.28098797798157 Progress at 16000 / 60327
# Time since last checkpoint 81.45869636535645 Progress at 17000 / 60327
# year failded {'id': 'A00198', 'title': 'Articles to be enquired of in the generall visitation of Edmonde Bisshoppe of London exercised by him the yeare of oure Lorde. 1.5.5.4. in the citie and diocese of London ...', 'author': ['Church of England', 'Diocese of London', 'Bonner', 'Bonner', 'Edmund'], 'pubplace': [], 'publisher': ['Iohannis Cawodi', 'Regiæ Maiestatis'], 'date': 'Anno. M.D.LIIII. mense Septembri]'}
# Time since last checkpoint 81.25085806846619 Progress at 18000 / 60327
# Time since last checkpoint 81.86516571044922 Progress at 19000 / 60327
# Time since last checkpoint 85.31918263435364 Progress at 20000 / 60327
# year failded {'id': 'A04632', 'title': 'The workes of Beniamin Ionson', 'author': ['Jonson, Ben', 'William'], 'pubplace': ['London'], 'publisher': ['Stansby', 'Meighen'], 'date': 'An⁰ D. 1616.'}
# year failded {'id': 'B05662', 'title': 'A proclamation for observing the staple-port at Camphire.', 'author': ['Scotland', 'Privy Council', 'Scotland', 'William', 'Mary'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# year failded {'id': 'B06146', 'title': 'To the right honourable Lord High Chancellor, and remanent lords of his Majesties most honourable Privy Council. The humble petition of his Majesties printer and servants.', 'pubplace': [], 'publisher': [], 'date': 'unknown', 'author': []}
# Time since last checkpoint 76.18773341178894 Progress at 21000 / 60327
# year failded {'id': 'B05711', 'title': 'A proclamation, indicting a solemn and publick thanksgiving throughout the Kingdom of Scotland, to be kept upon the ninth of September next, for His Majesties safe delivery from the late phanatical conspiracy against his Majesty, his royal Highness and government.', 'author': ['Scotland', 'Privy Council', 'Scotland', 'Charles II'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer'], 'date': 'Anno.'}
# year failded {'id': 'B03281', 'title': 'An elegy upon the most pious and incomparable Princess, Mary Queen of England, &c. who departed this mortal life, on Friday the 28th of December, at Kensignton. 1694.', 'pubplace': [], 'publisher': [], 'date': 'unknown', 'author': []}
# year failded {'id': 'B05609', 'title': 'Proclamation for a solemn national fast.', 'author': ['Scotland', 'Privy Council', 'Scotland', 'William II'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# year failded {'id': 'B05703', 'title': 'A proclamation for the security of ministers. At Edinburgh, the thirteenth day of June, one thousand six hundred and sixty seven.', 'author': ['Scotland', 'Charles II'], 'pubplace': ['Edinburgh'], 'publisher': ['Evan Tyler', 'Printer', 'Majesty'], 'date': 'Anno.'}
# Time since last checkpoint 56.526753664016724 Progress at 22000 / 60327
# Time since last checkpoint 66.6932201385498 Progress at 23000 / 60327
# year failded {'id': 'A36972', 'title': 'An essay towards the theory of the intelligible world intuitively considered designed for forty-nine parts : Part III : consisting of a preface, a postscript, and a little something between / by Gabriel John ; enriched with a faithful account of his ideal voyage, and illustrated with poems by several hands, as likewise with other strange things not insufferably clever, nor furiously to the purpose.', 'author': ["D'Urfey, Thomas"], 'edition': ['The archetypally second edition.'], 'pubplace': ['London'], 'publisher': [], 'date': 'Printed in the year one thousand seven hundred, &c.'}
# Time since last checkpoint 71.43951392173767 Progress at 24000 / 60327
# Time since last checkpoint 70.07916903495789 Progress at 25000 / 60327
# Time since last checkpoint 69.23910427093506 Progress at 26000 / 60327
# Time since last checkpoint 69.78778982162476 Progress at 27000 / 60327
# year failded {'id': 'A89106', 'title': 'A message sent from the city of London, to the King Majesty in the Isle of Wight, declaring their resolution touching the speedy bringing of His Majesty to His royall palace at White-Hall, and the manner thereof. Subscribed by the royall-hearted citizens. Also, the declaration of the Queen of England, concerning Her royall consort King Charles; and Her letter to the Prince of Wales, touching the Earl of Warwick. Agreed upon by the Queens Maiesty, and Her councell at St. Jermins, and published throughout the Kingdome of France.', 'author': [], 'pubplace': [], 'date': '4⁰.', 'publisher': []}
# Time since last checkpoint 69.75301742553711 Progress at 28000 / 60327
# Time since last checkpoint 71.17047715187073 Progress at 29000 / 60327
# Time since last checkpoint 72.61105394363403 Progress at 30000 / 60327
# year failded {'id': 'A69143', 'title': 'Miscellania or a treatise Contayning two hundred controuersiall animaduersions, conducing to the study of English controuersies in fayth, and religion. VVritten by N.N.P. and dedicated to the yonger sort of Catholike priests, and other students in the English seminaries beyond the seas. With a pareneticall conclusion vnto the said men.', 'author': ['Anderton', 'Lawrence'], 'pubplace': [], 'publisher': ['English College Press'], 'date': 'Printed Anno M. DC. XL.'}
# Time since last checkpoint 69.47734093666077 Progress at 31000 / 60327
# year failded {'id': 'A63691', 'title': 'A True relation of the great victory obtained by the Christian army over the Turks near the mountain Harsan in the neighbourhood of Syclos, from the camp of Electoral Highness of Bavaria near Barnowar the 14th of August, 1687.', 'pubplace': ['London'], 'publisher': ['Samuel Carr'], 'date': 'MDCLXXXVII.', 'author': []}
# Time since last checkpoint 69.54829907417297 Progress at 32000 / 60327
# Time since last checkpoint 70.75872159004211 Progress at 33000 / 60327
# Time since last checkpoint 74.61085057258606 Progress at 34000 / 60327
# year failded {'id': 'A22476', 'title': 'By the King a proclamation for the better ordering of those who repaire to the court, for their cure of the disease called the kings euill.', 'author': ['England', 'Wales', 'Charles', 'Charles I'], 'pubplace': ['London'], 'publisher': ['Bonham Norton', 'Iohn Bill', 'Printers', 'the Kings most Excellent Maiestie'], 'date': 'M.DC.XXVIII.'}
# Time since last checkpoint 77.82684206962585 Progress at 35000 / 60327
# year failded {'id': 'A72347', 'title': 'Certayne sermons appoynted by the Quenes Maiestie, to be declared and read, by all persones, vycars, and curates, euery Sondaye and holy daye in theyr churches : and by her Graces aduyse perused & ouer sene, for the better vnderstandyng of the simple people : newly imprinted in partes accordynge as is mencioned in the booke of commune prayers.', 'pubplace': ['London'], 'publisher': [], 'date': 'Anno M. D. L. ix.', 'author': []}
# Time since last checkpoint 77.543630361557 Progress at 36000 / 60327
# Time since last checkpoint 75.81407380104065 Progress at 37000 / 60327
# Time since last checkpoint 73.77143144607544 Progress at 38000 / 60327
# Time since last checkpoint 73.57654619216919 Progress at 39000 / 60327
# Time since last checkpoint 80.12531304359436 Progress at 40000 / 60327
# year failded {'id': 'A96564', 'title': 'By the King, a proclamation for a publick thanksgiving', 'author': ['England', 'Wales', 'William III'], 'pubplace': ['London'], 'publisher': ['Charles Bill', 'Thomas Newcomb'], 'date': '169⁵/₆.'}
# Time since last checkpoint 77.62066626548767 Progress at 41000 / 60327
# year failded {'id': 'A46389', 'title': 'The continuation of the laws of Jamaica passed by the Assembly, and confirmed by His Majesty in Council, December 26th, 1695 :being the second volume of the said laws.', 'author': ['Jamaica'], 'pubplace': ['London'], 'publisher': ['Charles Harper', 'Samuel Crouch'], 'date': 'MDCXCVIII.'}
# Time since last checkpoint 71.03654050827026 Progress at 42000 / 60327
# year failded {'id': 'A42887', 'title': 'God give you joy The hearty wish of a Christian friend to the bridegroom and the bride. A marriage-present for the new-married-couple: containing considerations and advices, in order to perswade young married people to begin the married life in the fear of the Lord. With directions and prayers. With plainness, intended for the meanest understanding. By one that desires to be a true son of the church of Christ, as by the gospel established.', 'pubplace': ['London'], 'publisher': [], 'date': 'Printed in the year,', 'author': []}
# year failded {'id': 'A48746', 'title': 'A project of a descent upon France by a person of quality.', 'author': ['Littleton', 'Edward'], 'pubplace': ['London'], 'publisher': ['Rich', 'Baldwin'], 'date': 'M DC XCI.'}
# Time since last checkpoint 70.2224326133728 Progress at 43000 / 60327
# year failded {'id': 'A45145', 'title': 'The obligation of human laws discussed. By J.H.', 'author': ['Humfrey, John,'], 'pubplace': ['London'], 'publisher': [], 'date': 'printed in the year,'}
# year failded {'id': 'A46690', 'title': 'A sermon preached at Bugbrook in Northamptonshire, May 15, 1642, upon the collection for Ireland condemned in the morning, in the church, before the whole congregation for popery, and in the afternoone there, for having many lyes in it of a high nature / published by the authour in a just vindication of himselfe from that unjust scandall.', 'author': ['Jay', 'George'], 'pubplace': ['London'], 'publisher': ['Harper'], 'date': 'M DC XLII.'}
# Time since last checkpoint 70.04120898246765 Progress at 44000 / 60327
# year failded {'id': 'A54279', 'title': 'A looking-glass for the Quakers: in two columns wherein they may in part see themselves, and may be seen by others. Vide, audi, judica. The first column is, what they formerly published against the Papists; and the other column is, what they published on their behalf, when uppermost. Phil. Anglus. Licensed, May 14. 1689.', 'author': ['Joseph'], 'pubplace': ['London'], 'publisher': [], 'date': 'printed in the year MDCLXXXIX. and are to be sold at several booksellers. Price two pence.'}
# Time since last checkpoint 71.03088784217834 Progress at 45000 / 60327
# year failded {'id': 'A58047', 'title': 'Solitude improved by divine meditation, or, A treatise proving the duty and demonstrating the necessity, excellency, usefulness, natures, kinds and requisites of divine meditation first intended for a person of honour, and now published for general use by Nathanael Ranew.', 'author': ['Ranew', 'Nathanael'], 'pubplace': ['London'], 'publisher': ['J.M.', 'Nathanael Ranew', 'Jonathon Robinson'], 'date': 'MDCLXX.'}
# year failded {'id': 'A53763', 'title': 'The Oxford-antiquity examined wherein is briefly shewn the notorious falshoods in the Greek manuscript, said to be translated by Humphrey Hody, B.D. of Wadham College, Oxon., which the better to recommend to the world, he entitles The unreasonableness of a separation from the bishops &c.', 'pubplace': ['London'], 'publisher': [], 'date': 'MDCXCI.', 'author': []}
# Time since last checkpoint 72.85454487800598 Progress at 46000 / 60327
# Time since last checkpoint 70.42165422439575 Progress at 47000 / 60327
# Time since last checkpoint 87.10873985290527 Progress at 48000 / 60327
# year failded {'id': 'A14647', 'title': 'A breefe of scripture disproving the principall points of popery / gathered by J.W. for the use of the people  of his owne charge.', 'author': ['Waker', 'John'], 'pubplace': ['Dublin'], 'publisher': ['Society of Stationers'], 'date': 'Imprinted Anno Dom. cIc. Ic. c.xxiiii.'}
# year failded {'id': 'A12851', 'title': '[Accidentia ex Stanbrigiana editione nuper recognita et castigata]', 'author': ['Stanbridge', 'John'], 'pubplace': ['Jmprinted', 'London', 'Fletestrete'], 'publisher': ['James Gauer', 'Sonne'], 'date': 'In the yere of our lord god M. CCCCC. and .xxxix.'}
# Time since last checkpoint 94.90454626083374 Progress at 49000 / 60327
# year failded {'id': 'A03048', 'title': 'The grete herball whiche geueth parfyt knowlege and vnderstandyng of all maner of herbes [and] there gracyous vertues whiche god hath ordeyned for our prosperous welfare and helth, for they hele [and] cure all maner of dyseases and sekenesses that fall or mysfortune to all maner of creatoures of god created, practysed by many expert and wyse maysters, as Auicenna [and] other. [et]c. Also it geueth full parfyte vnderstandynge of the booke lately prentyd by me (Peter treueris) named the noble experiens of the vertuous handwarke of surgery.', 'pubplace': ['London', 'Southwarke'], 'publisher': ['Peter Treueris'], 'date': 'In the yere of our lorde god. M.D.xxvi. the xxvii. day of Iuly]', 'author': []}
# Time since last checkpoint 96.05331611633301 Progress at 50000 / 60327
# Time since last checkpoint 98.82789731025696 Progress at 51000 / 60327
# year failded {'id': 'B43913', 'title': 'By His Highnes Council in Scotland for the government thereof. Whereas it hath the most wise God in his providence to take out of this world the most serene and renowned Oliver late Lord Protector of this Commonwealth and his said highnesse having in his life-time according to the humble petition and advice declared and appointed the most noble and illustrious the Lord Richard ...', 'author': ['Scotland', 'Privy Council'], 'pubplace': ['Edinburgh'], 'publisher': ['Christopher Higgins', 'Harts Close'], 'date': 'Anno Donini [sic],'}
# year failded {'id': 'B07986', 'title': 'A proclamation against the home-loyterers, recusants to the common cause, within the colledge of iustice, as followeth, [by] Tho. Plaine Clerke.', 'author': ['Plaine Clerke', 'Tho'], 'pubplace': [], 'publisher': [], 'date': 'unknown'}
# year failded {'id': 'B08002', 'title': 'A commemoration of the inestimable graces and benefites of God, infused through the bryght lyght of the knowledge of his holy word, in our most dradde soueraigne lorde Henry the eyght, by the grace of God kyng of Englande and of Fraunce, defender of the the fayth, lorde of Irelande, and in erth the supreme heed next and immediate vnder Christe of the Churche of Englande, with hartye prayse and thankes gyuyng vnto God for the same, / composed uppon the glad prophecy and ioyefull psalme of Benedictus dominus deus Israel. &c..', 'author': ['Pylbarough', 'John'], 'pubplace': [], 'publisher': ['Thomæ Bertheleti', 'Cum'], 'date': 'Anno .M.D.XL..'}
# year failded {'id': 'B05184', 'title': 'Act for levying of sea-men Edinburgh, the fourth day of May 1693.', 'author': ['Scotland', 'Parliament', 'Committee of Estates'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# Time since last checkpoint 78.49349856376648 Progress at 52000 / 60327
# year failded {'id': 'B03351', 'title': 'The form of the proceeding to the funeral of Her late Majesty Queen Mary II. Of blessed memory, from the royal palace of Whitehall to the Collegiate Church at Westminster; the 5th day of this instant March, 1694/5. To begin at twelve a clock. (To be punctually observed by all persons therein concerned.)', 'pubplace': ['London', 'Edinburgh'], 'publisher': ['Edw', 'Andrew Anderson', 'Printer', 'Majesty'], 'date': '169⁴/₅ ;', 'author': []}
# year failded {'id': 'B05363', 'title': 'Edinburgh, May 14. 1679. Forasmuch as his Majesty by a proclamation of the fourth of this instant, did, for the horrid discovery of the murther of the late Archbishop of St. Andrews, require and command all the heretors and masters of Fyfe and Kinross, to being their tenents, cottars, and servants, and others dwelling on their lands, to the respective places and tyets therein mentioned ...', 'author': ['Scotland', 'Privy Council', 'Scotland', 'Charles II'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# Time since last checkpoint 75.90897512435913 Progress at 53000 / 60327
# year failded {'id': 'B05170', 'title': 'Act concerning citations in process for treason. Edinburgh, May 1. 1685.', 'author': ['Scotland', 'Parliament', 'Committee of Estates'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer'], 'date': 'Anno .'}
# year failded {'id': 'B01408', 'title': 'Answers for the brewars [sic] within the town of Edinburgh and suburbs, and the priviledge of the Shire of Mid-lothian : to the reasons offered to their Majesties High Commissioner, and the right honourable the Estates of Parliament, by the magistrates of Edinburgh, in realtion to an imposition of two pennies upon the pynt of ale, now craved by them for the space of thirty years, upon pretence of payment of the towns debts.', 'author': ['Scotland', 'Parliament'], 'pubplace': [], 'publisher': [], 'date': 'unknown'}
# year failded {'id': 'B05521', 'title': 'A proclamation anent the ministers. At Edinburgh, the sixth day of August, one thousand six hundred and eighty nine years.', 'author': ['Scotland', 'Privy Council', 'Scotland', 'William', 'Mary'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# Time since last checkpoint 77.8575119972229 Progress at 54000 / 60327
# year failded {'id': 'B06540', 'title': 'An advantageous method of extricating the nation out of its difficulties. Humbly proposed by Thomas Whately.', 'author': ['Whately', 'Thomas'], 'pubplace': ['London'], 'publisher': ['T. Milbourn', 'Carter', 'Parliament', 'Plow', 'the Royal Exchange'], 'date': '169⁵/₆.'}
# year failded {'id': 'B05722', 'title': 'A proclamation, prorogating the dyet for inbringing the accompts due by the forces.', 'author': ['Scotland', 'Privy Council', 'Scotland', 'William', 'Mary'], 'pubplace': ['Edinburgh'], 'publisher': ['Andrew Anderson', 'Printer', 'Majesty'], 'date': 'Anno.'}
# Time since last checkpoint 75.64626502990723 Progress at 55000 / 60327
# Time since last checkpoint 73.87866950035095 Progress at 56000 / 60327
# Time since last checkpoint 74.37023830413818 Progress at 57000 / 60327
# Time since last checkpoint 78.67002534866333 Progress at 58000 / 60327
# Time since last checkpoint 80.31290555000305 Progress at 59000 / 60327
# year failded {'id': 'B12637', 'title': 'A proclamacion sette furth by the kynges Maiestie lycencyng the exchaunges and rechaunges of money to be frequented and used, in all partes of his highnes realmes and dominions.', 'author': ['England', 'Wales', 'Edward VI', 'Edward VI', 'King of England'], 'pubplace': ['London'], 'publisher': ['Richardus Grafton'], 'date': 'A. M. D. LII.'}
# year failded {'id': 'B11729', 'title': 'Here begynneth the holy lyfe and history of saynt werburge very frutefull for all christen people to rede.', 'author': ['Bradshaw', 'Henry'], 'pubplace': ['London'], 'publisher': ['Richarde Pynson'], 'date': 'A⁰. M.D.xxi[1521]]'}
# Time since last checkpoint 95.50208330154419 Progress at 60000 / 60327

# %%
byid = {}

for text in texts:
    if text.get('date', ''):
        try:
            byid[text['id']] = int("".join(filter(lambda x: x.isnumeric(),  text['date'])))
        except:
            byid[text['id']] = ''
            pass

# %%
import json
clusters = []

with open('../data/test_cluster_parse.json') as f:    
    clusters = json.load(f)

# %%
# Way too slow need to transform these into csv imports

import time
start = time.time()
for i, cluster in enumerate(list(clusters.keys())[10000:]):
    fragment_node = ''
    try:
        fragment_node = Fragment.nodes.get(cluster_id=cluster)
    except:
        fragment_node = Fragment(cluster_id=cluster).save()
        
    for text in clusters[cluster]:
        try:
            db_text = Text.nodes.get(text_id=text['text_id'])
            db_text.fragment.connect(fragment_node)
            db_text.save()
        except:
            pass
    if i % 100000 == 999:
        print(f'Time passed since last checkpoint {time.time() - start}, progress at {i + 1} / {len(clusters)}')
# Out:
# Time passed since last checkpoint 109.93622469902039, progress at 1000 / 3707553

# %%
from pandas.io.json import json_normalize
df = json_normalize(clusters)
df.to_csv('test.csv')

# %%
class Tester(StructuredNode):
    texts = RelationshipTo()
